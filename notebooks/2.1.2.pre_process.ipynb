# %% [markdown]
# # PreProcess Step
#
# * Encode categorical data
# * normalize the features

# %% [markdown]
# ### Load Data

# %%
site_input_dir = "processed_data"
site_name = "HCBHSGSG_Bank_9"

# %%
import os
import random
import string

import pandas as pd

dataset_names = ["train", "test"]
datasets = {}

for ds_name in dataset_names:
    file_name = os.path.join(site_input_dir, site_name, f"{ds_name}_enrichment.csv")
    df = pd.read_csv(file_name)
    datasets[ds_name] = df
    print(df)
# Out:
#       Unnamed: 0            Timestamp  Fraud_Label Transaction_ID    User_ID  \
# 0              0  2023-07-21 00:39:00            0      TXN_15663  USER_7774
# 1              1  2023-07-21 00:40:00            0      TXN_16666  USER_2491
# 2              2  2023-07-21 01:16:00            0      TXN_13793  USER_7209
# 3              3  2023-07-21 02:21:00            0      TXN_33256  USER_9146
# 4              4  2023-07-21 04:37:00            0      TXN_49460  USER_6842
# ...          ...                  ...          ...            ...        ...
# 3596        3596  2023-12-31 20:35:00            1      TXN_37832  USER_5830
# 3597        3597  2023-12-31 21:38:00            1      TXN_38974  USER_4134
# 3598        3598  2023-12-31 21:52:00            0      TXN_25394  USER_8356
# 3599        3599  2023-12-31 21:55:00            0      TXN_41124  USER_7621
# 3600        3600  2023-12-31 22:35:00            0      TXN_10811  USER_1721
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                 183.33   ATM Withdrawal         57770.62      Tablet
# 1                  30.14    Bank Transfer         13256.87      Mobile
# 2                  51.05   ATM Withdrawal         78156.21      Laptop
# 3                  59.16           Online         16293.82      Tablet
# 4                  20.76              POS          9549.72      Laptop
# ...                  ...              ...              ...         ...
# 3596               50.72   ATM Withdrawal         62311.01      Laptop
# 3597               85.95           Online         93524.52      Tablet
# 3598                1.38   ATM Withdrawal          6957.28      Laptop
# 3599                2.28   ATM Withdrawal         35539.86      Laptop
# 3600               40.90           Online         98065.59      Mobile
#
#      Location  ... Beneficiary_BIC  Currency_Country  trans_volume  \
# 0       Tokyo  ...        ZNZZAU3M            Sydney             2
# 1       Tokyo  ...        YSYCESMM            Mumbai             2
# 2       Tokyo  ...        HCBHSGSG             Tokyo             1
# 3       Tokyo  ...        YSYCESMM            Mumbai             1
# 4       Tokyo  ...        ZHSZUS33          New York             1
# ...       ...  ...             ...               ...           ...
# 3596    Tokyo  ...        YSYCESMM            Mumbai             1
# 3597    Tokyo  ...        YSYCESMM            Mumbai             3
# 3598    Tokyo  ...        ZNZZAU3M            Sydney             3
# 3599    Tokyo  ...        YXRXGB22            London             3
# 3600    Tokyo  ...        ZNZZAU3M            Sydney             1
#
#       total_amount  average_amount  hist_trans_volume hist_total_amount  \
# 0           213.47         106.735               1145         112754.07
# 1           213.47         106.735               1145         112754.07
# 2            51.05          51.050               1140         115504.34
# 3            59.16          59.160               1145         114992.08
# 4            20.76          20.760               1131         108775.02
# ...            ...             ...                ...               ...
# 3596         50.72          50.720               1145         114992.08
# 3597         89.61          29.870               1145         114992.08
# 3598         89.61          29.870               1145         114992.08
# 3599         89.61          29.870               1145         114992.08
# 3600         40.90          40.900               1145         112754.07
#
#       hist_average_amount     x2_y1     x3_y2
# 0               98.475170  0.093218  0.093218
# 1               98.475170  0.093218  0.093218
# 2              101.319596  0.044781  0.044781
# 3              100.429764  0.051668  0.051668
# 4               96.175968  0.018355  0.036042
# ...                   ...       ...       ...
# 3596           100.429764  0.044297  0.044297
# 3597           100.429764  0.026087  0.026087
# 3598           100.429764  0.026087  0.026087
# 3599           100.429764  0.026087  0.026087
# 3600            98.475170  0.035721  0.035721
#
# [3601 rows x 35 columns]
#       Unnamed: 0            Timestamp  Fraud_Label Transaction_ID    User_ID  \
# 0              0  2023-07-21 01:54:00            0      TXN_39762  USER_7063
# 1              1  2023-07-21 09:25:00            0      TXN_22459  USER_2259
# 2              2  2023-07-21 17:57:00            1      TXN_33514  USER_4766
# 3              3  2023-07-21 18:12:00            0      TXN_10419  USER_4791
# 4              4  2023-07-22 01:11:00            0      TXN_47563  USER_9811
# ...          ...                  ...          ...            ...        ...
# 997          997  2023-12-31 03:41:00            1       TXN_1418  USER_1526
# 998          998  2023-12-31 08:54:00            0      TXN_30172  USER_7247
# 999          999  2023-12-31 12:57:00            1      TXN_22253  USER_7616
# 1000        1000  2023-12-31 14:55:00            0       TXN_1318  USER_5795
# 1001        1001  2023-12-31 15:39:00            0      TXN_25612  USER_6739
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                  10.33   ATM Withdrawal         60220.07      Mobile
# 1                  99.19    Bank Transfer         69805.95      Mobile
# 2                  48.21    Bank Transfer         16321.84      Tablet
# 3                 109.85    Bank Transfer         91778.71      Laptop
# 4                 296.30           Online         18695.87      Laptop
# ...                  ...              ...              ...         ...
# 997               194.31    Bank Transfer         48651.30      Tablet
# 998                 0.47              POS         53547.52      Tablet
# 999               137.89   ATM Withdrawal         68654.39      Laptop
# 1000              109.93              POS         25626.10      Tablet
# 1001               30.50           Online         86680.53      Laptop
#
#      Location  ... Beneficiary_BIC  Currency_Country  trans_volume  \
# 0       Tokyo  ...        ZNZZAU3M            Sydney             1
# 1       Tokyo  ...        HCBHSGSG             Tokyo             1
# 2       Tokyo  ...        YSYCESMM            Mumbai             1
# 3       Tokyo  ...        ZHSZUS33          New York             1
# 4       Tokyo  ...        YSYCESMM            Mumbai             1
# ...       ...  ...             ...               ...           ...
# 997     Tokyo  ...        HCBHSGSG             Tokyo             1
# 998     Tokyo  ...        YSYCESMM            Mumbai             1
# 999     Tokyo  ...        ZHSZUS33          New York             1
# 1000    Tokyo  ...        ZNZZAU3M            Sydney             1
# 1001    Tokyo  ...        YXRXGB22            London             1
#
#       total_amount  average_amount  hist_trans_volume hist_total_amount  \
# 0            10.33           10.33               1145         112754.07
# 1            99.19           99.19               1140         115504.34
# 2            48.21           48.21               1145         114992.08
# 3           109.85          109.85               1131         108775.02
# 4           296.30          296.30               1145         114992.08
# ...            ...             ...                ...               ...
# 997         194.31          194.31               1140         115504.34
# 998           0.47            0.47               1145         114992.08
# 999         137.89          137.89               1131         108775.02
# 1000        109.93          109.93               1145         112754.07
# 1001         30.50           30.50               1056         104216.90
#
#       hist_average_amount     x2_y1     x3_y2
# 0               98.475170  0.009022  0.009022
# 1              101.319596  0.087009  0.087009
# 2              100.429764  0.042105  0.042105
# 3               96.175968  0.097126  0.190712
# 4              100.429764  0.258777  0.258777
# ...                   ...       ...       ...
# 997            101.319596  0.170447  0.170447
# 998            100.429764  0.000410  0.000410
# 999             96.175968  0.121919  0.239392
# 1000            98.475170  0.096009  0.096009
# 1001            98.690246  0.028883  0.028883
#
# [1002 rows x 35 columns]

# %% [markdown]
# ### Categorical encoding

# %%
category_columns = [
    "Currency_Country",
    "Beneficiary_BIC",
    "Currency",
    "Transaction_ID",
    "Receiver_BIC",
    "Sender_BIC",
]

for ds_name in dataset_names:
    df = datasets[ds_name]
    df_encoded = pd.get_dummies(df, columns=category_columns)
    print(df_encoded)
# Out:
#       Unnamed: 0            Timestamp  Fraud_Label    User_ID  \
# 0              0  2023-07-21 00:39:00            0  USER_7774
# 1              1  2023-07-21 00:40:00            0  USER_2491
# 2              2  2023-07-21 01:16:00            0  USER_7209
# 3              3  2023-07-21 02:21:00            0  USER_9146
# 4              4  2023-07-21 04:37:00            0  USER_6842
# ...          ...                  ...          ...        ...
# 3596        3596  2023-12-31 20:35:00            1  USER_5830
# 3597        3597  2023-12-31 21:38:00            1  USER_4134
# 3598        3598  2023-12-31 21:52:00            0  USER_8356
# 3599        3599  2023-12-31 21:55:00            0  USER_7621
# 3600        3600  2023-12-31 22:35:00            0  USER_1721
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                 183.33   ATM Withdrawal         57770.62      Tablet
# 1                  30.14    Bank Transfer         13256.87      Mobile
# 2                  51.05   ATM Withdrawal         78156.21      Laptop
# 3                  59.16           Online         16293.82      Tablet
# 4                  20.76              POS          9549.72      Laptop
# ...                  ...              ...              ...         ...
# 3596               50.72   ATM Withdrawal         62311.01      Laptop
# 3597               85.95           Online         93524.52      Tablet
# 3598                1.38   ATM Withdrawal          6957.28      Laptop
# 3599                2.28   ATM Withdrawal         35539.86      Laptop
# 3600               40.90           Online         98065.59      Mobile
#
#      Location Merchant_Category  ...  Receiver_BIC_HCBHSGSG  \
# 0       Tokyo       Restaurants  ...                  False
# 1       Tokyo       Electronics  ...                  False
# 2       Tokyo          Clothing  ...                  False
# 3       Tokyo          Clothing  ...                  False
# 4       Tokyo         Groceries  ...                  False
# ...       ...               ...  ...                    ...
# 3596    Tokyo         Groceries  ...                  False
# 3597    Tokyo       Electronics  ...                   True
# 3598    Tokyo            Travel  ...                   True
# 3599    Tokyo            Travel  ...                  False
# 3600    Tokyo         Groceries  ...                  False
#
#       Receiver_BIC_SHSHKHH1  Receiver_BIC_WPUWDEFF  Receiver_BIC_XITXUS33  \
# 0                     False                   True                  False
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                     False                   True                  False
# 4                     False                  False                   True
# ...                     ...                    ...                    ...
# 3596                  False                  False                  False
# 3597                  False                  False                  False
# 3598                  False                  False                  False
# 3599                  False                  False                  False
# 3600                  False                  False                  False
#
#       Receiver_BIC_YMNYFRPP Receiver_BIC_YSYCESMM  Receiver_BIC_YXRXGB22  \
# 0                     False                 False                  False
# 1                     False                 False                  False
# 2                     False                 False                  False
# 3                     False                 False                  False
# 4                     False                 False                  False
# ...                     ...                   ...                    ...
# 3596                  False                 False                  False
# 3597                  False                 False                  False
# 3598                  False                 False                  False
# 3599                  False                 False                  False
# 3600                   True                 False                  False
#
#       Receiver_BIC_ZHSZUS33 Receiver_BIC_ZNZZAU3M  Sender_BIC_HCBHSGSG
# 0                     False                 False                 True
# 1                      True                 False                 True
# 2                      True                 False                 True
# 3                     False                 False                 True
# 4                     False                 False                 True
# ...                     ...                   ...                  ...
# 3596                  False                  True                 True
# 3597                  False                 False                 True
# 3598                  False                 False                 True
# 3599                   True                 False                 True
# 3600                  False                 False                 True
#
# [3601 rows x 3645 columns]
#       Unnamed: 0            Timestamp  Fraud_Label    User_ID  \
# 0              0  2023-07-21 01:54:00            0  USER_7063
# 1              1  2023-07-21 09:25:00            0  USER_2259
# 2              2  2023-07-21 17:57:00            1  USER_4766
# 3              3  2023-07-21 18:12:00            0  USER_4791
# 4              4  2023-07-22 01:11:00            0  USER_9811
# ...          ...                  ...          ...        ...
# 997          997  2023-12-31 03:41:00            1  USER_1526
# 998          998  2023-12-31 08:54:00            0  USER_7247
# 999          999  2023-12-31 12:57:00            1  USER_7616
# 1000        1000  2023-12-31 14:55:00            0  USER_5795
# 1001        1001  2023-12-31 15:39:00            0  USER_6739
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                  10.33   ATM Withdrawal         60220.07      Mobile
# 1                  99.19    Bank Transfer         69805.95      Mobile
# 2                  48.21    Bank Transfer         16321.84      Tablet
# 3                 109.85    Bank Transfer         91778.71      Laptop
# 4                 296.30           Online         18695.87      Laptop
# ...                  ...              ...              ...         ...
# 997               194.31    Bank Transfer         48651.30      Tablet
# 998                 0.47              POS         53547.52      Tablet
# 999               137.89   ATM Withdrawal         68654.39      Laptop
# 1000              109.93              POS         25626.10      Tablet
# 1001               30.50           Online         86680.53      Laptop
#
#      Location Merchant_Category  ...  Receiver_BIC_HCBHSGSG  \
# 0       Tokyo       Electronics  ...                  False
# 1       Tokyo            Travel  ...                  False
# 2       Tokyo       Electronics  ...                  False
# 3       Tokyo         Groceries  ...                  False
# 4       Tokyo          Clothing  ...                  False
# ...       ...               ...  ...                    ...
# 997     Tokyo         Groceries  ...                   True
# 998     Tokyo       Restaurants  ...                  False
# 999     Tokyo          Clothing  ...                  False
# 1000    Tokyo       Electronics  ...                  False
# 1001    Tokyo            Travel  ...                   True
#
#       Receiver_BIC_SHSHKHH1  Receiver_BIC_WPUWDEFF  Receiver_BIC_XITXUS33  \
# 0                     False                  False                   True
# 1                     False                  False                  False
# 2                     False                  False                  False
# 3                      True                  False                  False
# 4                     False                  False                  False
# ...                     ...                    ...                    ...
# 997                   False                  False                  False
# 998                   False                  False                  False
# 999                   False                  False                  False
# 1000                  False                   True                  False
# 1001                  False                  False                  False
#
#       Receiver_BIC_YMNYFRPP Receiver_BIC_YSYCESMM  Receiver_BIC_YXRXGB22  \
# 0                     False                 False                  False
# 1                     False                 False                  False
# 2                     False                  True                  False
# 3                     False                 False                  False
# 4                     False                 False                   True
# ...                     ...                   ...                    ...
# 997                   False                 False                  False
# 998                   False                 False                  False
# 999                   False                 False                  False
# 1000                  False                 False                  False
# 1001                  False                 False                  False
#
#       Receiver_BIC_ZHSZUS33 Receiver_BIC_ZNZZAU3M  Sender_BIC_HCBHSGSG
# 0                     False                 False                 True
# 1                     False                 False                 True
# 2                     False                 False                 True
# 3                     False                 False                 True
# 4                     False                 False                 True
# ...                     ...                   ...                  ...
# 997                   False                 False                 True
# 998                   False                 False                 True
# 999                    True                 False                 True
# 1000                  False                 False                 True
# 1001                  False                 False                 True
#
# [1002 rows x 1058 columns]

# %% [markdown]
# ### Normalization

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'Fraud_Label', 'Transaction_ID', 'User_ID',
#        'Transaction_Amount', 'Transaction_Type', 'Account_Balance',
#        'Device_Type', 'Location', 'Merchant_Category', 'IP_Address_Flag',
#        'Previous_Fraudulent_Activity', 'Daily_Transaction_Count',
#        'Avg_Transaction_Amount_7d', 'Failed_Transaction_Count_7d', 'Card_Type',
#        'Card_Age', 'Transaction_Distance', 'Authentication_Method',
#        'Risk_Score', 'Is_Weekend', 'Sender_BIC', 'Receiver_BIC', 'Currency',
#        'Beneficiary_BIC', 'Currency_Country', 'trans_volume', 'total_amount',
#        'average_amount', 'hist_trans_volume', 'hist_total_amount',
#        'hist_average_amount', 'x2_y1', 'x3_y2'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler


processed_dfs = {}

numerical_columns = [
    "Timestamp",
    "Fraud_Label",
    "Transaction_Amount",
    "trans_volume",
    "total_amount",
    "average_amount",
    "hist_trans_volume",
    "hist_total_amount",
    "hist_average_amount",
    "x2_y1",
    "x3_y2",
]

for ds_name in dataset_names:
    df = datasets[ds_name]

    # Convert 'Timestamp' column to datetime
    df["Timestamp"] = pd.to_datetime(df["Timestamp"])
    # Convert datetime to Unix timestamp
    df["Timestamp"] = df["Timestamp"].astype(int) / 10**9  # convert to seconds

    # Separate numerical and categorical features
    numerical_features = df[numerical_columns]
    categorical_features = df[category_columns]

    # Initialize the MinMaxScaler (or StandardScaler)
    scaler = MinMaxScaler()

    # Fit and transform the numerical data
    numerical_normalized = pd.DataFrame(
        scaler.fit_transform(numerical_features), columns=numerical_features.columns
    )

    # Combine the normalized numerical features with the categorical features
    df_combined = pd.concat([categorical_features, numerical_normalized], axis=1)

    #     # one-hot encoding
    #     df_combined = pd.get_dummies(df_combined, columns=category_columns)

    print("Combined DataFrame with Normalized Numerical Features:")
    print(df_combined)

    processed_dfs[ds_name] = df_combined
# Out:
# Combined DataFrame with Normalized Numerical Features:
#      Currency_Country Beneficiary_BIC Currency Transaction_ID Receiver_BIC  \
# 0              Sydney        ZNZZAU3M      AUD      TXN_15663     WPUWDEFF
# 1              Mumbai        YSYCESMM      INR      TXN_16666     ZHSZUS33
# 2               Tokyo        HCBHSGSG      JPY      TXN_13793     ZHSZUS33
# 3              Mumbai        YSYCESMM      INR      TXN_33256     WPUWDEFF
# 4            New York        ZHSZUS33      USD      TXN_49460     XITXUS33
# ...               ...             ...      ...            ...          ...
# 3596           Mumbai        YSYCESMM      INR      TXN_37832     ZNZZAU3M
# 3597           Mumbai        YSYCESMM      INR      TXN_38974     HCBHSGSG
# 3598           Sydney        ZNZZAU3M      AUD      TXN_25394     HCBHSGSG
# 3599           London        YXRXGB22      GBP      TXN_41124     ZHSZUS33
# 3600           Sydney        ZNZZAU3M      AUD      TXN_10811     YMNYFRPP
#
#      Sender_BIC  Timestamp  Fraud_Label  Transaction_Amount  trans_volume  \
# 0      HCBHSGSG   0.000000          0.0            0.220491           0.2
# 1      HCBHSGSG   0.000004          0.0            0.036149           0.2
# 2      HCBHSGSG   0.000157          0.0            0.061311           0.0
# 3      HCBHSGSG   0.000432          0.0            0.071070           0.0
# 4      HCBHSGSG   0.001008          0.0            0.024861           0.0
# ...         ...        ...          ...                 ...           ...
# 3596   HCBHSGSG   0.999492          1.0            0.060914           0.0
# 3597   HCBHSGSG   0.999759          1.0            0.103308           0.4
# 3598   HCBHSGSG   0.999818          0.0            0.001540           0.4
# 3599   HCBHSGSG   0.999831          0.0            0.002623           0.4
# 3600   HCBHSGSG   1.000000          0.0            0.049097           0.0
#
#       total_amount  average_amount  hist_trans_volume  hist_total_amount  \
# 0         0.105870        0.156747           1.000000           0.756342
# 1         0.105870        0.156747           1.000000           0.756342
# 2         0.025280        0.074893           0.943820           1.000000
# 3         0.029304        0.086815           1.000000           0.954617
# 4         0.010251        0.030369           0.842697           0.403822
# ...            ...             ...                ...                ...
# 3596      0.025117        0.074408           1.000000           0.954617
# 3597      0.044413        0.043760           1.000000           0.954617
# 3598      0.044413        0.043760           1.000000           0.954617
# 3599      0.044413        0.043760           1.000000           0.954617
# 3600      0.020244        0.059974           1.000000           0.756342
#
#       hist_average_amount     x2_y1     x3_y2
# 0                0.447000  0.156062  0.106390
# 1                0.447000  0.156062  0.106390
# 2                1.000000  0.074894  0.051056
# 3                0.827003  0.086435  0.058924
# 4                0.000000  0.030612  0.041073
# ...                   ...       ...       ...
# 3596             0.827003  0.074083  0.050504
# 3597             0.827003  0.043569  0.029702
# 3598             0.827003  0.043569  0.029702
# 3599             0.827003  0.043569  0.029702
# 3600             0.447000  0.059712  0.040706
#
# [3601 rows x 17 columns]
# Combined DataFrame with Normalized Numerical Features:
#      Currency_Country Beneficiary_BIC Currency Transaction_ID Receiver_BIC  \
# 0              Sydney        ZNZZAU3M      AUD      TXN_39762     XITXUS33
# 1               Tokyo        HCBHSGSG      JPY      TXN_22459     FBSFCHZH
# 2              Mumbai        YSYCESMM      INR      TXN_33514     YSYCESMM
# 3            New York        ZHSZUS33      USD      TXN_10419     SHSHKHH1
# 4              Mumbai        YSYCESMM      INR      TXN_47563     YXRXGB22
# ...               ...             ...      ...            ...          ...
# 997             Tokyo        HCBHSGSG      JPY       TXN_1418     HCBHSGSG
# 998            Mumbai        YSYCESMM      INR      TXN_30172     FBSFCHZH
# 999          New York        ZHSZUS33      USD      TXN_22253     ZHSZUS33
# 1000           Sydney        ZNZZAU3M      AUD       TXN_1318     WPUWDEFF
# 1001           London        YXRXGB22      GBP      TXN_25612     HCBHSGSG
#
#      Sender_BIC  Timestamp  Fraud_Label  Transaction_Amount  trans_volume  \
# 0      HCBHSGSG   0.000000          0.0            0.013797           0.0
# 1      HCBHSGSG   0.001915          0.0            0.132595           0.0
# 2      HCBHSGSG   0.004088          1.0            0.064439           0.0
# 3      HCBHSGSG   0.004152          0.0            0.146847           0.0
# 4      HCBHSGSG   0.005931          0.0            0.396115           0.0
# ...         ...        ...          ...                 ...           ...
# 997    HCBHSGSG   0.996952          1.0            0.259763           0.0
# 998    HCBHSGSG   0.998281          0.0            0.000615           0.0
# 999    HCBHSGSG   0.999312          1.0            0.184334           0.0
# 1000   HCBHSGSG   0.999813          0.0            0.146954           0.0
# 1001   HCBHSGSG   1.000000          0.0            0.040763           0.0
#
#       total_amount  average_amount  hist_trans_volume  hist_total_amount  \
# 0         0.012943        0.013797           1.000000           0.756342
# 1         0.124387        0.132595           0.943820           1.000000
# 2         0.060450        0.064439           1.000000           0.954617
# 3         0.137756        0.146847           0.842697           0.403822
# 4         0.371593        0.396115           1.000000           0.954617
# ...            ...             ...                ...                ...
# 997       0.243682        0.259763           0.943820           1.000000
# 998       0.000577        0.000615           1.000000           0.954617
# 999       0.172923        0.184334           0.842697           0.403822
# 1000      0.137857        0.146954           1.000000           0.756342
# 1001      0.038239        0.040763           0.000000           0.000000
#
#       hist_average_amount     x2_y1     x3_y2
# 0                0.447000  0.013628  0.006941
# 1                1.000000  0.131549  0.066995
# 2                0.827003  0.063651  0.032416
# 3                0.000000  0.146847  0.146853
# 4                0.827003  0.391272  0.199267
# ...                   ...       ...       ...
# 997              1.000000  0.257712  0.131248
# 998              0.827003  0.000607  0.000309
# 999              0.000000  0.184334  0.184339
# 1000             0.447000  0.145157  0.073926
# 1001             0.488814  0.043659  0.022235
#
# [1002 rows x 17 columns]

# %%
for name in processed_dfs:
    site_dir = os.path.join(site_input_dir, site_name)
    os.makedirs(site_dir, exist_ok=True)
    pre_processed_file_name = os.path.join(site_dir, f"{name}_normalized.csv")
    print(pre_processed_file_name)
    processed_dfs[name].to_csv(pre_processed_file_name)
# Out:
# processed_data/HCBHSGSG_Bank_9/train_normalized.csv
# processed_data/HCBHSGSG_Bank_9/test_normalized.csv

# %% [markdown]
# Let's go back to the [XGBoost Notebook](../xgboost.ipynb)
