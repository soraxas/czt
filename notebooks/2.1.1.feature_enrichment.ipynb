# %% [markdown]
# ## Feature Enrichment
#
# ### Historical data enrichment
#
# Pick one client (Site, aka sender_BIC) to do the enrichment as every site will be the same process

# %%
site_input_dir = "./processed_data"
site_name = "HCBHSGSG_Bank_9"

# %%
import os
import random
import string

import pandas as pd

history_file_name = os.path.join(site_input_dir, site_name, "history.csv")
df_history = pd.read_csv(history_file_name)
df_history
# Out:
#      Transaction_ID    User_ID  Transaction_Amount Transaction_Type  \
# 0         TXN_31639  USER_7709              257.68              POS
# 1         TXN_39239  USER_4475               99.42   ATM Withdrawal
# 2         TXN_25673  USER_6728               49.57           Online
# 3         TXN_42035  USER_6935              179.96              POS
# 4         TXN_22339  USER_6566               57.20   ATM Withdrawal
# ...             ...        ...                 ...              ...
# 5612      TXN_37621  USER_5430              117.85           Online
# 5613      TXN_11380  USER_4892               91.13           Online
# 5614      TXN_43130  USER_3308              165.04              POS
# 5615      TXN_12293  USER_6058               12.32   ATM Withdrawal
# 5616      TXN_39441  USER_4551              217.70              POS
#
#                 Timestamp  Account_Balance Device_Type Location  \
# 0     2023-01-01 01:06:00         61383.97      Tablet    Tokyo
# 1     2023-01-01 01:11:00         88959.44      Laptop    Tokyo
# 2     2023-01-01 01:13:00         96771.99      Laptop    Tokyo
# 3     2023-01-01 02:17:00         77053.09      Mobile    Tokyo
# 4     2023-01-01 02:25:00         54934.85      Laptop    Tokyo
# ...                   ...              ...         ...      ...
# 5612  2023-07-20 19:14:00         45831.27      Laptop    Tokyo
# 5613  2023-07-20 20:18:00         27299.21      Mobile    Tokyo
# 5614  2023-07-20 20:27:00         90191.79      Mobile    Tokyo
# 5615  2023-07-20 22:27:00         12385.73      Mobile    Tokyo
# 5616  2023-07-21 00:38:00         34954.23      Mobile    Tokyo
#
#      Merchant_Category  IP_Address_Flag  ...  Transaction_Distance  \
# 0            Groceries                0  ...               1099.31
# 1               Travel                0  ...               3412.79
# 2            Groceries                0  ...               4104.06
# 3             Clothing                0  ...               3412.87
# 4             Clothing                0  ...               2728.42
# ...                ...              ...  ...                   ...
# 5612       Electronics                0  ...               3833.14
# 5613         Groceries                0  ...               3099.80
# 5614            Travel                0  ...               3092.85
# 5615       Electronics                0  ...                854.99
# 5616          Clothing                0  ...               1578.56
#
#       Authentication_Method  Risk_Score  Is_Weekend Fraud_Label  Sender_BIC  \
# 0                  Password      0.8859           0           1    HCBHSGSG
# 1                 Biometric      0.0152           0           1    HCBHSGSG
# 2                  Password      0.6304           1           1    HCBHSGSG
# 3                       OTP      0.7885           0           0    HCBHSGSG
# 4                       PIN      0.7521           0           1    HCBHSGSG
# ...                     ...         ...         ...         ...         ...
# 5612                    OTP      0.3042           0           1    HCBHSGSG
# 5613                    OTP      0.1203           0           1    HCBHSGSG
# 5614                    OTP      0.1452           0           0    HCBHSGSG
# 5615                    OTP      0.6103           1           1    HCBHSGSG
# 5616              Biometric      0.6869           0           0    HCBHSGSG
#
#       Receiver_BIC Currency  Beneficiary_BIC  Currency_Country
# 0         FBSFCHZH      INR         YSYCESMM            Mumbai
# 1         FBSFCHZH      JPY         HCBHSGSG             Tokyo
# 2         YMNYFRPP      USD         XITXUS33          New York
# 3         YMNYFRPP      USD         ZHSZUS33          New York
# 4         FBSFCHZH      USD         XITXUS33          New York
# ...            ...      ...              ...               ...
# 5612      XITXUS33      USD         XITXUS33          New York
# 5613      SHSHKHH1      GBP         YXRXGB22            London
# 5614      YMNYFRPP      JPY         HCBHSGSG             Tokyo
# 5615      ZHSZUS33      USD         ZHSZUS33          New York
# 5616      XITXUS33      INR         YSYCESMM            Mumbai
#
# [5617 rows x 26 columns]

# %%
history_summary = (
    df_history.groupby("Currency")
    .agg(
        hist_trans_volume=("Transaction_ID", "count"),
        hist_total_amount=("Transaction_Amount", "sum"),
        hist_average_amount=("Transaction_Amount", "mean"),
    )
    .reset_index()
)

history_summary
# Out:
#   Currency  hist_trans_volume  hist_total_amount  hist_average_amount
# 0      AUD               1145          112754.07            98.475170
# 1      GBP               1056          104216.90            98.690246
# 2      INR               1145          114992.08           100.429764
# 3      JPY               1140          115504.34           101.319596
# 4      USD               1131          108775.02            96.175968

# %% [markdown]
# # Enrich Feature with Currency

# %%
import pandas as pd

dataset_names = ["train", "test"]
results = {}

temp_ds_df = {}
temp_resampled_df = {}


for ds_name in dataset_names:
    file_name = os.path.join(site_input_dir, site_name, f"{ds_name}.csv")
    ds_df = pd.read_csv(file_name)
    ds_df["Timestamp"] = pd.to_datetime(ds_df["Timestamp"])

    # Set the Time column as the index
    ds_df.set_index("Timestamp", inplace=True)

    resampled_df = (
        ds_df.resample("1H")
        .agg(
            trans_volume=("Transaction_ID", "count"),
            total_amount=("Transaction_Amount", "sum"),
            average_amount=("Transaction_Amount", "mean"),
        )
        .reset_index()
    )

    temp_ds_df[ds_name] = ds_df
    temp_resampled_df[ds_name] = resampled_df
# Out:
# /tmp/ipykernel_24583/1206980181.py:19: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   ds_df.resample("1H")
# /tmp/ipykernel_24583/1206980181.py:19: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   ds_df.resample("1H")

# %%
for ds_name in dataset_names:

    ds_df = temp_ds_df[ds_name]
    resampled_df = temp_resampled_df[ds_name]

    c_df = ds_df[["Currency"]].resample("1H").agg({"Currency": "first"}).reset_index()
    # Add Currency_Country to the resampled data by joining with the original DataFrame
    resampled_df2 = pd.merge(resampled_df, c_df, on="Timestamp")
    resampled_df3 = pd.merge(resampled_df2, history_summary, on="Currency")
    resampled_df4 = resampled_df3.copy()
    resampled_df4["x2_y1"] = (
        resampled_df4["average_amount"] / resampled_df4["hist_trans_volume"]
    )

    ds_df = ds_df.sort_values("Timestamp")
    resampled_df4 = resampled_df4.sort_values("Timestamp")

    merged_df = pd.merge_asof(ds_df, resampled_df4, on="Timestamp")
    merged_df = merged_df.drop(columns=["Currency_y"]).rename(
        columns={"Currency_x": "Currency"}
    )

    results[ds_name] = merged_df

print(results)
# Out:
# {'train':                Timestamp  Fraud_Label Transaction_ID    User_ID  \
# 0    2023-07-21 00:39:00            0      TXN_15663  USER_7774
# 1    2023-07-21 00:40:00            0      TXN_16666  USER_2491
# 2    2023-07-21 01:16:00            0      TXN_13793  USER_7209
# 3    2023-07-21 02:21:00            0      TXN_33256  USER_9146
# 4    2023-07-21 04:37:00            0      TXN_49460  USER_6842
# ...                  ...          ...            ...        ...
# 3584 2023-12-31 20:35:00            1      TXN_37832  USER_5830
# 3585 2023-12-31 21:38:00            1      TXN_38974  USER_4134
# 3586 2023-12-31 21:52:00            0      TXN_25394  USER_8356
# 3587 2023-12-31 21:55:00            0      TXN_41124  USER_7621
# 3588 2023-12-31 22:35:00            0      TXN_10811  USER_1721
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                 183.33   ATM Withdrawal         57770.62      Tablet
# 1                  30.14    Bank Transfer         13256.87      Mobile
# 2                  51.05   ATM Withdrawal         78156.21      Laptop
# 3                  59.16           Online         16293.82      Tablet
# 4                  20.76              POS          9549.72      Laptop
# ...                  ...              ...              ...         ...
# 3584               50.72   ATM Withdrawal         62311.01      Laptop
# 3585               85.95           Online         93524.52      Tablet
# 3586                1.38   ATM Withdrawal          6957.28      Laptop
# 3587                2.28   ATM Withdrawal         35539.86      Laptop
# 3588               40.90           Online         98065.59      Mobile
#
#      Location Merchant_Category  ...  Currency  Beneficiary_BIC  \
# 0       Tokyo       Restaurants  ...       AUD         ZNZZAU3M
# 1       Tokyo       Electronics  ...       INR         YSYCESMM
# 2       Tokyo          Clothing  ...       JPY         HCBHSGSG
# 3       Tokyo          Clothing  ...       INR         YSYCESMM
# 4       Tokyo         Groceries  ...       USD         ZHSZUS33
# ...       ...               ...  ...       ...              ...
# 3584    Tokyo         Groceries  ...       INR         YSYCESMM
# 3585    Tokyo       Electronics  ...       INR         YSYCESMM
# 3586    Tokyo            Travel  ...       AUD         ZNZZAU3M
# 3587    Tokyo            Travel  ...       GBP         YXRXGB22
# 3588    Tokyo         Groceries  ...       AUD         ZNZZAU3M
#
#       Currency_Country  trans_volume  total_amount average_amount  \
# 0               Sydney             2        213.47        106.735
# 1               Mumbai             2        213.47        106.735
# 2                Tokyo             1         51.05         51.050
# 3               Mumbai             1         59.16         59.160
# 4             New York             1         20.76         20.760
# ...                ...           ...           ...            ...
# 3584            Mumbai             1         50.72         50.720
# 3585            Mumbai             3         89.61         29.870
# 3586            Sydney             3         89.61         29.870
# 3587            London             3         89.61         29.870
# 3588            Sydney             1         40.90         40.900
#
#       hist_trans_volume  hist_total_amount hist_average_amount     x2_y1
# 0                  1145          112754.07           98.475170  0.093218
# 1                  1145          112754.07           98.475170  0.093218
# 2                  1140          115504.34          101.319596  0.044781
# 3                  1145          114992.08          100.429764  0.051668
# 4                  1131          108775.02           96.175968  0.018355
# ...                 ...                ...                 ...       ...
# 3584               1145          114992.08          100.429764  0.044297
# 3585               1145          114992.08          100.429764  0.026087
# 3586               1145          114992.08          100.429764  0.026087
# 3587               1145          114992.08          100.429764  0.026087
# 3588               1145          112754.07           98.475170  0.035721
#
# [3589 rows x 33 columns], 'test':                Timestamp  Fraud_Label Transaction_ID    User_ID  \
# 0    2023-07-21 01:54:00            0      TXN_39762  USER_7063
# 1    2023-07-21 09:25:00            0      TXN_22459  USER_2259
# 2    2023-07-21 17:57:00            1      TXN_33514  USER_4766
# 3    2023-07-21 18:12:00            0      TXN_10419  USER_4791
# 4    2023-07-22 01:11:00            0      TXN_47563  USER_9811
# ...                  ...          ...            ...        ...
# 997  2023-12-31 03:41:00            1       TXN_1418  USER_1526
# 998  2023-12-31 08:54:00            0      TXN_30172  USER_7247
# 999  2023-12-31 12:57:00            1      TXN_22253  USER_7616
# 1000 2023-12-31 14:55:00            0       TXN_1318  USER_5795
# 1001 2023-12-31 15:39:00            0      TXN_25612  USER_6739
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                  10.33   ATM Withdrawal         60220.07      Mobile
# 1                  99.19    Bank Transfer         69805.95      Mobile
# 2                  48.21    Bank Transfer         16321.84      Tablet
# 3                 109.85    Bank Transfer         91778.71      Laptop
# 4                 296.30           Online         18695.87      Laptop
# ...                  ...              ...              ...         ...
# 997               194.31    Bank Transfer         48651.30      Tablet
# 998                 0.47              POS         53547.52      Tablet
# 999               137.89   ATM Withdrawal         68654.39      Laptop
# 1000              109.93              POS         25626.10      Tablet
# 1001               30.50           Online         86680.53      Laptop
#
#      Location Merchant_Category  ...  Currency  Beneficiary_BIC  \
# 0       Tokyo       Electronics  ...       AUD         ZNZZAU3M
# 1       Tokyo            Travel  ...       JPY         HCBHSGSG
# 2       Tokyo       Electronics  ...       INR         YSYCESMM
# 3       Tokyo         Groceries  ...       USD         ZHSZUS33
# 4       Tokyo          Clothing  ...       INR         YSYCESMM
# ...       ...               ...  ...       ...              ...
# 997     Tokyo         Groceries  ...       JPY         HCBHSGSG
# 998     Tokyo       Restaurants  ...       INR         YSYCESMM
# 999     Tokyo          Clothing  ...       USD         ZHSZUS33
# 1000    Tokyo       Electronics  ...       AUD         ZNZZAU3M
# 1001    Tokyo            Travel  ...       GBP         YXRXGB22
#
#       Currency_Country  trans_volume  total_amount average_amount  \
# 0               Sydney             1         10.33          10.33
# 1                Tokyo             1         99.19          99.19
# 2               Mumbai             1         48.21          48.21
# 3             New York             1        109.85         109.85
# 4               Mumbai             1        296.30         296.30
# ...                ...           ...           ...            ...
# 997              Tokyo             1        194.31         194.31
# 998             Mumbai             1          0.47           0.47
# 999           New York             1        137.89         137.89
# 1000            Sydney             1        109.93         109.93
# 1001            London             1         30.50          30.50
#
#       hist_trans_volume  hist_total_amount hist_average_amount     x2_y1
# 0                  1145          112754.07           98.475170  0.009022
# 1                  1140          115504.34          101.319596  0.087009
# 2                  1145          114992.08          100.429764  0.042105
# 3                  1131          108775.02           96.175968  0.097126
# 4                  1145          114992.08          100.429764  0.258777
# ...                 ...                ...                 ...       ...
# 997                1140          115504.34          101.319596  0.170447
# 998                1145          114992.08          100.429764  0.000410
# 999                1131          108775.02           96.175968  0.121919
# 1000               1145          112754.07           98.475170  0.096009
# 1001               1056          104216.90           98.690246  0.028883
#
# [1002 rows x 33 columns]}
# /tmp/ipykernel_24583/3196226655.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   c_df = ds_df[["Currency"]].resample("1H").agg({"Currency": "first"}).reset_index()
# /tmp/ipykernel_24583/3196226655.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   c_df = ds_df[["Currency"]].resample("1H").agg({"Currency": "first"}).reset_index()

# %% [markdown]
# # Enrich feature for beneficiary country

# %%
history_summary2 = (
    df_history.groupby("Beneficiary_BIC")
    .agg(
        hist_trans_volume=("Transaction_ID", "count"),
        hist_total_amount=("Transaction_Amount", "sum"),
        hist_average_amount=("Transaction_Amount", "mean"),
    )
    .reset_index()
)

history_summary2
# Out:
#   Beneficiary_BIC  hist_trans_volume  hist_total_amount  hist_average_amount
# 0        HCBHSGSG               1140          115504.34           101.319596
# 1        XITXUS33                555           54129.23            97.530144
# 2        YSYCESMM               1145          114992.08           100.429764
# 3        YXRXGB22               1056          104216.90            98.690246
# 4        ZHSZUS33                576           54645.79            94.871163
# 5        ZNZZAU3M               1145          112754.07            98.475170

# %%
import pandas as pd

dataset_names = ["train", "test"]
results2 = {}
for ds_name in dataset_names:
    ds_df = temp_ds_df[ds_name]
    resampled_df = temp_resampled_df[ds_name]

    c_df = (
        ds_df[["Beneficiary_BIC"]]
        .resample("1H")
        .agg({"Beneficiary_BIC": "first"})
        .reset_index()
    )

    # Add Beneficiary_BIC to the resampled data by joining with the original DataFrame
    resampled_df2 = pd.merge(resampled_df, c_df, on="Timestamp")

    resampled_df3 = pd.merge(resampled_df2, history_summary2, on="Beneficiary_BIC")

    resampled_df4 = resampled_df3.copy()
    resampled_df4["x3_y2"] = (
        resampled_df4["average_amount"] / resampled_df4["hist_trans_volume"]
    )

    ds_df = ds_df.sort_values("Timestamp")
    resampled_df4 = resampled_df4.sort_values("Timestamp")

    merged_df2 = pd.merge_asof(ds_df, resampled_df4, on="Timestamp")
    merged_df2 = merged_df2.drop(columns=["Beneficiary_BIC_y"]).rename(
        columns={"Beneficiary_BIC_x": "Beneficiary_BIC"}
    )

    results2[ds_name] = merged_df2

print(results2)
# Out:
# {'train':                Timestamp  Fraud_Label Transaction_ID    User_ID  \
# 0    2023-07-21 00:39:00            0      TXN_15663  USER_7774
# 1    2023-07-21 00:40:00            0      TXN_16666  USER_2491
# 2    2023-07-21 01:16:00            0      TXN_13793  USER_7209
# 3    2023-07-21 02:21:00            0      TXN_33256  USER_9146
# 4    2023-07-21 04:37:00            0      TXN_49460  USER_6842
# ...                  ...          ...            ...        ...
# 3584 2023-12-31 20:35:00            1      TXN_37832  USER_5830
# 3585 2023-12-31 21:38:00            1      TXN_38974  USER_4134
# 3586 2023-12-31 21:52:00            0      TXN_25394  USER_8356
# 3587 2023-12-31 21:55:00            0      TXN_41124  USER_7621
# 3588 2023-12-31 22:35:00            0      TXN_10811  USER_1721
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                 183.33   ATM Withdrawal         57770.62      Tablet
# 1                  30.14    Bank Transfer         13256.87      Mobile
# 2                  51.05   ATM Withdrawal         78156.21      Laptop
# 3                  59.16           Online         16293.82      Tablet
# 4                  20.76              POS          9549.72      Laptop
# ...                  ...              ...              ...         ...
# 3584               50.72   ATM Withdrawal         62311.01      Laptop
# 3585               85.95           Online         93524.52      Tablet
# 3586                1.38   ATM Withdrawal          6957.28      Laptop
# 3587                2.28   ATM Withdrawal         35539.86      Laptop
# 3588               40.90           Online         98065.59      Mobile
#
#      Location Merchant_Category  ...  Currency  Beneficiary_BIC  \
# 0       Tokyo       Restaurants  ...       AUD         ZNZZAU3M
# 1       Tokyo       Electronics  ...       INR         YSYCESMM
# 2       Tokyo          Clothing  ...       JPY         HCBHSGSG
# 3       Tokyo          Clothing  ...       INR         YSYCESMM
# 4       Tokyo         Groceries  ...       USD         ZHSZUS33
# ...       ...               ...  ...       ...              ...
# 3584    Tokyo         Groceries  ...       INR         YSYCESMM
# 3585    Tokyo       Electronics  ...       INR         YSYCESMM
# 3586    Tokyo            Travel  ...       AUD         ZNZZAU3M
# 3587    Tokyo            Travel  ...       GBP         YXRXGB22
# 3588    Tokyo         Groceries  ...       AUD         ZNZZAU3M
#
#       Currency_Country  trans_volume  total_amount average_amount  \
# 0               Sydney             2        213.47        106.735
# 1               Mumbai             2        213.47        106.735
# 2                Tokyo             1         51.05         51.050
# 3               Mumbai             1         59.16         59.160
# 4             New York             1         20.76         20.760
# ...                ...           ...           ...            ...
# 3584            Mumbai             1         50.72         50.720
# 3585            Mumbai             3         89.61         29.870
# 3586            Sydney             3         89.61         29.870
# 3587            London             3         89.61         29.870
# 3588            Sydney             1         40.90         40.900
#
#       hist_trans_volume  hist_total_amount hist_average_amount     x3_y2
# 0                  1145          112754.07           98.475170  0.093218
# 1                  1145          112754.07           98.475170  0.093218
# 2                  1140          115504.34          101.319596  0.044781
# 3                  1145          114992.08          100.429764  0.051668
# 4                   576           54645.79           94.871163  0.036042
# ...                 ...                ...                 ...       ...
# 3584               1145          114992.08          100.429764  0.044297
# 3585               1145          114992.08          100.429764  0.026087
# 3586               1145          114992.08          100.429764  0.026087
# 3587               1145          114992.08          100.429764  0.026087
# 3588               1145          112754.07           98.475170  0.035721
#
# [3589 rows x 33 columns], 'test':                Timestamp  Fraud_Label Transaction_ID    User_ID  \
# 0    2023-07-21 01:54:00            0      TXN_39762  USER_7063
# 1    2023-07-21 09:25:00            0      TXN_22459  USER_2259
# 2    2023-07-21 17:57:00            1      TXN_33514  USER_4766
# 3    2023-07-21 18:12:00            0      TXN_10419  USER_4791
# 4    2023-07-22 01:11:00            0      TXN_47563  USER_9811
# ...                  ...          ...            ...        ...
# 997  2023-12-31 03:41:00            1       TXN_1418  USER_1526
# 998  2023-12-31 08:54:00            0      TXN_30172  USER_7247
# 999  2023-12-31 12:57:00            1      TXN_22253  USER_7616
# 1000 2023-12-31 14:55:00            0       TXN_1318  USER_5795
# 1001 2023-12-31 15:39:00            0      TXN_25612  USER_6739
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                  10.33   ATM Withdrawal         60220.07      Mobile
# 1                  99.19    Bank Transfer         69805.95      Mobile
# 2                  48.21    Bank Transfer         16321.84      Tablet
# 3                 109.85    Bank Transfer         91778.71      Laptop
# 4                 296.30           Online         18695.87      Laptop
# ...                  ...              ...              ...         ...
# 997               194.31    Bank Transfer         48651.30      Tablet
# 998                 0.47              POS         53547.52      Tablet
# 999               137.89   ATM Withdrawal         68654.39      Laptop
# 1000              109.93              POS         25626.10      Tablet
# 1001               30.50           Online         86680.53      Laptop
#
#      Location Merchant_Category  ...  Currency  Beneficiary_BIC  \
# 0       Tokyo       Electronics  ...       AUD         ZNZZAU3M
# 1       Tokyo            Travel  ...       JPY         HCBHSGSG
# 2       Tokyo       Electronics  ...       INR         YSYCESMM
# 3       Tokyo         Groceries  ...       USD         ZHSZUS33
# 4       Tokyo          Clothing  ...       INR         YSYCESMM
# ...       ...               ...  ...       ...              ...
# 997     Tokyo         Groceries  ...       JPY         HCBHSGSG
# 998     Tokyo       Restaurants  ...       INR         YSYCESMM
# 999     Tokyo          Clothing  ...       USD         ZHSZUS33
# 1000    Tokyo       Electronics  ...       AUD         ZNZZAU3M
# 1001    Tokyo            Travel  ...       GBP         YXRXGB22
#
#       Currency_Country  trans_volume  total_amount average_amount  \
# 0               Sydney             1         10.33          10.33
# 1                Tokyo             1         99.19          99.19
# 2               Mumbai             1         48.21          48.21
# 3             New York             1        109.85         109.85
# 4               Mumbai             1        296.30         296.30
# ...                ...           ...           ...            ...
# 997              Tokyo             1        194.31         194.31
# 998             Mumbai             1          0.47           0.47
# 999           New York             1        137.89         137.89
# 1000            Sydney             1        109.93         109.93
# 1001            London             1         30.50          30.50
#
#       hist_trans_volume  hist_total_amount hist_average_amount     x3_y2
# 0                  1145          112754.07           98.475170  0.009022
# 1                  1140          115504.34          101.319596  0.087009
# 2                  1145          114992.08          100.429764  0.042105
# 3                   576           54645.79           94.871163  0.190712
# 4                  1145          114992.08          100.429764  0.258777
# ...                 ...                ...                 ...       ...
# 997                1140          115504.34          101.319596  0.170447
# 998                1145          114992.08          100.429764  0.000410
# 999                 576           54645.79           94.871163  0.239392
# 1000               1145          112754.07           98.475170  0.096009
# 1001               1056          104216.90           98.690246  0.028883
#
# [1002 rows x 33 columns]}
# /tmp/ipykernel_24583/2998991707.py:11: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .resample("1H")
# /tmp/ipykernel_24583/2998991707.py:11: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .resample("1H")

# %%
final_results = {}
for name in results:
    df = results[name]
    df2 = results2[name]
    df3 = df2[["Timestamp", "Beneficiary_BIC", "x3_y2"]].copy()
    df4 = pd.merge(df, df3, on=["Timestamp", "Beneficiary_BIC"])
    final_results[name] = df4


for name in final_results:
    site_dir = os.path.join(site_input_dir, site_name)
    os.makedirs(site_dir, exist_ok=True)
    enrich_file_name = os.path.join(site_dir, f"{name}_enrichment.csv")
    print(enrich_file_name)
    final_results[name].to_csv(enrich_file_name)

final_results["train"]
# Out:
# ./processed_data/HCBHSGSG_Bank_9/train_enrichment.csv
# ./processed_data/HCBHSGSG_Bank_9/test_enrichment.csv
#                Timestamp  Fraud_Label Transaction_ID    User_ID  \
# 0    2023-07-21 00:39:00            0      TXN_15663  USER_7774
# 1    2023-07-21 00:40:00            0      TXN_16666  USER_2491
# 2    2023-07-21 01:16:00            0      TXN_13793  USER_7209
# 3    2023-07-21 02:21:00            0      TXN_33256  USER_9146
# 4    2023-07-21 04:37:00            0      TXN_49460  USER_6842
# ...                  ...          ...            ...        ...
# 3596 2023-12-31 20:35:00            1      TXN_37832  USER_5830
# 3597 2023-12-31 21:38:00            1      TXN_38974  USER_4134
# 3598 2023-12-31 21:52:00            0      TXN_25394  USER_8356
# 3599 2023-12-31 21:55:00            0      TXN_41124  USER_7621
# 3600 2023-12-31 22:35:00            0      TXN_10811  USER_1721
#
#       Transaction_Amount Transaction_Type  Account_Balance Device_Type  \
# 0                 183.33   ATM Withdrawal         57770.62      Tablet
# 1                  30.14    Bank Transfer         13256.87      Mobile
# 2                  51.05   ATM Withdrawal         78156.21      Laptop
# 3                  59.16           Online         16293.82      Tablet
# 4                  20.76              POS          9549.72      Laptop
# ...                  ...              ...              ...         ...
# 3596               50.72   ATM Withdrawal         62311.01      Laptop
# 3597               85.95           Online         93524.52      Tablet
# 3598                1.38   ATM Withdrawal          6957.28      Laptop
# 3599                2.28   ATM Withdrawal         35539.86      Laptop
# 3600               40.90           Online         98065.59      Mobile
#
#      Location Merchant_Category  ...  Beneficiary_BIC  Currency_Country  \
# 0       Tokyo       Restaurants  ...         ZNZZAU3M            Sydney
# 1       Tokyo       Electronics  ...         YSYCESMM            Mumbai
# 2       Tokyo          Clothing  ...         HCBHSGSG             Tokyo
# 3       Tokyo          Clothing  ...         YSYCESMM            Mumbai
# 4       Tokyo         Groceries  ...         ZHSZUS33          New York
# ...       ...               ...  ...              ...               ...
# 3596    Tokyo         Groceries  ...         YSYCESMM            Mumbai
# 3597    Tokyo       Electronics  ...         YSYCESMM            Mumbai
# 3598    Tokyo            Travel  ...         ZNZZAU3M            Sydney
# 3599    Tokyo            Travel  ...         YXRXGB22            London
# 3600    Tokyo         Groceries  ...         ZNZZAU3M            Sydney
#
#       trans_volume  total_amount  average_amount hist_trans_volume  \
# 0                2        213.47         106.735              1145
# 1                2        213.47         106.735              1145
# 2                1         51.05          51.050              1140
# 3                1         59.16          59.160              1145
# 4                1         20.76          20.760              1131
# ...            ...           ...             ...               ...
# 3596             1         50.72          50.720              1145
# 3597             3         89.61          29.870              1145
# 3598             3         89.61          29.870              1145
# 3599             3         89.61          29.870              1145
# 3600             1         40.90          40.900              1145
#
#       hist_total_amount  hist_average_amount     x2_y1     x3_y2
# 0             112754.07            98.475170  0.093218  0.093218
# 1             112754.07            98.475170  0.093218  0.093218
# 2             115504.34           101.319596  0.044781  0.044781
# 3             114992.08           100.429764  0.051668  0.051668
# 4             108775.02            96.175968  0.018355  0.036042
# ...                 ...                  ...       ...       ...
# 3596          114992.08           100.429764  0.044297  0.044297
# 3597          114992.08           100.429764  0.026087  0.026087
# 3598          114992.08           100.429764  0.026087  0.026087
# 3599          114992.08           100.429764  0.026087  0.026087
# 3600          112754.07            98.475170  0.035721  0.035721
#
# [3601 rows x 34 columns]

# %% [markdown]
# Let's go back to the [XGBoost Notebook](../xgboost.ipynb)
